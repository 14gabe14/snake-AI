# %%
from agent import train
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train(n_games=2000, double_dqn=True)
# Out:
# Game: 2000 Score: 10 Record: 51
# Best score: 51
