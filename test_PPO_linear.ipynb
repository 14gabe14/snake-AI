# %%
from PPO_agent import train
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train(20000)
# Out:
# Game 20000, Score: 0, Record: 33
