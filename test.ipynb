# %%
from agent import train
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train("linear")

# %%
from CSnake import play
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
play()
# Out:
# Episode 0 - Step 55 - Epsilon 0.9986259277152086 - Mean Reward 44.0 - Mean Length 55.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.565 - Time 2021-04-07T18:22:57
# Episode 20 - Step 843 - Epsilon 0.9791452679531444 - Mean Reward 29.571 - Mean Length 40.143 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 8.717 - Time 2021-04-07T18:23:05
# Episode 40 - Step 1572 - Epsilon 0.9614617548819225 - Mean Reward 27.78 - Mean Length 38.341 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.949 - Time 2021-04-07T18:23:13
# Episode 60 - Step 2283 - Epsilon 0.9445225535985307 - Mean Reward 27.311 - Mean Length 37.426 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.768 - Time 2021-04-07T18:23:21
# Episode 80 - Step 2935 - Epsilon 0.9292514427563742 - Mean Reward 26.346 - Mean Length 36.235 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.163 - Time 2021-04-07T18:23:28
# ---------------------------------------------------------------------------
# ...

# %%
print("hello")
# Out:
# hello
