# %%
from agent import train
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2da0ffaf5447> in <module>
# ----> 1 train()
#
# c:\Users\Usuario\Documents\programs\snake-ai\snake-AI\agent.py in train()
#     132
#     133         # train short memory
# --> 134         agent.train_short_memory(state_old, final_move, reward, state_new, done)
#     135
#     136         # remember
#
# c:\Users\Usuario\Documents\programs\snake-ai\snake-AI\agent.py in train_short_memory(self, state, action, reward, next_state, done)
#      88
#      89     def train_short_memory(self, state, action, reward, next_state, done):
# ---> 90         self.trainer.train_step(state, action, reward, next_state, done)
#      91
#      92     def get_action(self, state):
#
# c:\Users\Usuario\Documents\programs\snake-ai\snake-AI\model.py in train_step(self, state, action, reward, next_state, done)
# ...
