# %%
from agent import train
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
train(2000)
# Out:
# Game: 2000 Score: 13 Record: 43
# Best score: 43
